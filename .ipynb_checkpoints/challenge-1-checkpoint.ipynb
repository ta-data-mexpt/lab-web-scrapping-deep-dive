# %%
import requests
# First, we need to import the requests library, for it is the based for api scraping

# %%
respuesta = requests.get('https://api.github.com/repos/ta-data-mexpt/lab-api-scavenger/forks')
# This is the url for our bootcamp :)
resultados = respuesta.json()
# We need to convert the data into json, so it can be usable
resultados
# We get to see the results from this calling
# Out:
# [{'id': 261928840,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNjE5Mjg4NDA=',
#   'name': 'lab-api-scavenger',
#   'full_name': 'zk97/lab-api-scavenger',
#   'private': False,
#   'owner': {'login': 'zk97',
#    'id': 10248069,
#    'node_id': 'MDQ6VXNlcjEwMjQ4MDY5',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/10248069?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zk97',
#    'html_url': 'https://github.com/zk97',
#    'followers_url': 'https://api.github.com/users/zk97/followers',
#    'following_url': 'https://api.github.com/users/zk97/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/zk97/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/zk97/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/zk97/subscriptions',
#    'organizations_url': 'https://api.github.com/users/zk97/orgs',
#    'repos_url': 'https://api.github.com/users/zk97/repos',
# ...

# %%
len(resultados)
# We need to know how many forks this repo has
# Out:
# 8

# %%
resultados[0]['language']
# We try to find what is the name for the atribute we are looking for

# %%
languages = [i['language'] for i in resultados]
# list comprehension to iterate in every fork and get language, to append them into a list called 'laguages'

# %%
languages
# Out:
# [None, None, None, None, None, None, None, None]

# %%
# All these forks have no language attached to them
